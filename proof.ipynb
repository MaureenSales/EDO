# %%
import utils as utils
import ode_solver as solver

function_srt = "x**2 - y**2"
tagsPoints = ["x", "y"]
valuesEuler = solver.euler_method(function_srt, 0, 1, 0.1, 40)
valuesImproved = solver.euler_improved_method(function_srt, 0, 1, 0.1, 40)
valuesRK4 = solver.RK4(function_srt, 0, 1, 0.1, 40)

dfEuler = utils.Convert_to_DF(valuesEuler, tagsPoints)
dfImproved = utils.Convert_to_DF(valuesImproved, tagsPoints)
dfRK4 = utils.Convert_to_DF(valuesRK4, tagsPoints)

dfs = [dfEuler, dfImproved, dfRK4]
tags = ["Euler's Method", "Improved Euler's Method", "Runge-Kutta 4th Order Method"]
utils.Combine_DataFrames(tags, dfs)
# Out:
#    Euler's Method           Improved Euler's Method            \
#                 x         y                       x         y
# 0             0.0  1.000000                     0.0  1.000000
# 1             0.1  0.900000                     0.1  0.910000
# 2             0.2  0.820000                     0.2  0.836800
# 3             0.3  0.756760                     0.3  0.778584
# 4             0.4  0.708491                     0.4  0.734350
# 5             0.5  0.674295                     0.5  0.703636
# 6             0.6  0.653828                     0.6  0.686320
# 7             0.7  0.647079                     0.7  0.682473
# 8             0.8  0.654208                     0.8  0.692230
# 9             0.9  0.675409                     0.9  0.715686
# 10            1.0  0.710791                     1.0  0.752790
# 11            1.1  0.760269                     1.1  0.803265
# 12            1.2  0.823468                     1.2  0.866545
# 13            1.3  0.899658                     1.3  0.941746
# 14            1.4  0.987720                     1.4  1.027672
# 15            1.5  1.086161                     1.5  1.122863
# 16            1.6  1.193186                     1.6  1.225685
# 17            1.7  1.306817                     1.7  1.334431
# 18            1.8  1.425040                     1.8  1.447442
# 19            1.9  1.545966                     1.9  1.563206
# 20            2.0  1.667965                     2.0  1.680432
# 21            2.1  1.789754                     2.1  1.798090
# 22            2.2  1.910432                     2.2  1.915424
# 23            2.3  2.029457                     2.3  2.031921
# 24            2.4  2.146587                     2.4  2.147280
# 25            2.5  2.261804                     2.5  2.261362
# 26            2.6  2.375228                     2.6  2.374146
# 27            2.7  2.487057                     2.7  2.485686
# 28            2.8  2.597512                     2.8  2.596080
# 29            2.9  2.706805                     2.9  2.705445
# 30            3.0  2.815126                     3.0  2.813902
# 31            3.1  2.922632                     3.1  2.921567
# 32            3.2  3.029454                     3.2  3.028544
# 33            3.3  3.135695                     3.3  3.134923
# 34            3.4  3.241437                     3.4  3.240784
# 35            3.5  3.346746                     3.5  3.346191
# 36            3.6  3.451675                     3.6  3.451202
# 37            3.7  3.556269                     3.7  3.555862
# 38            3.8  3.660564                     3.8  3.660211
# 39            3.9  3.764591                     3.9  3.764282
# 40            4.0  3.868376                     4.0  3.868104
#
#    Runge-Kutta 4th Order Method
#                               x         y
# 0                           0.0  1.000000
# 1                           0.1  0.909410
# 2                           0.2  0.835786
# 3                           0.3  0.777238
# 4                           0.4  0.732728
# 5                           0.5  0.701769
# 6                           0.6  0.684230
# 7                           0.7  0.680177
# 8                           0.8  0.689749
# 9                           0.9  0.713043
# 10                          1.0  0.750017
# 11                          1.1  0.800405
# 12                          1.2  0.863651
# 13                          1.3  0.938882
# 14                          1.4  1.024908
# 15                          1.5  1.120274
# 16                          1.6  1.223340
# 17                          1.7  1.332391
# 18                          1.8  1.445747
# 19                          1.9  1.561876
# 20                          2.0  1.679461
# 21                          2.1  1.797454
# 22                          2.2  1.915078
# 23                          2.3  2.031813
# 24                          2.4  2.147353
# 25                          2.5  2.261563
# 26                          2.6  2.374427
# 27                          2.7  2.486009
# 28                          2.8  2.596415
# 29                          2.9  2.705773
# 30                          3.0  2.814211
# 31                          3.1  2.921851
# 32                          3.2  3.028799
# 33                          3.3  3.135151
# 34                          3.4  3.240985
# 35                          3.5  3.346370
# 36                          3.6  3.451360
# 37                          3.7  3.556003
# 38                          3.8  3.660337
# 39                          3.9  3.764396
# 40                          4.0  3.868207

# %%
traces = []
traces.append(utils.Get_Trace(valuesEuler, "Euler's Method")[0])
traces.append(utils.Get_Trace(valuesImproved, "Improved Euler's Method")[0])
traces.append(utils.Get_Trace(valuesRK4, "Runge-Kutta 4th Order Method")[0])
utils.Get_Comparison_Traces(traces).show()

# %%
import utils as utils
import ode_solver as solver

function_srt = "y**2"
tagsPoints = ["x", "y"]
valuesEuler = solver.euler_method(function_srt, 0, 1, 0.05, 10)
valuesImproved = solver.euler_improved_method(function_srt, 0, 1, 0.05, 10)
valuesRK4 = solver.RK4(function_srt, 0, 1, 0.05, 10)

dfEuler = utils.Convert_to_DF(valuesEuler, tagsPoints)
dfImproved = utils.Convert_to_DF(valuesImproved, tagsPoints)
dfRK4 = utils.Convert_to_DF(valuesRK4, tagsPoints)

dfs = [dfEuler, dfImproved, dfRK4]
tags = ["Euler's Method", "Improved Euler's Method", "Runge-Kutta 4th Order Method"]
utils.Combine_DataFrames(tags, dfs)
# Out:
#    Euler's Method           Improved Euler's Method            \
#                 x         y                       x         y
# 0            0.00  1.000000                    0.00  1.000000
# 1            0.05  1.050000                    0.05  1.052563
# 2            0.10  1.105125                     NaN       NaN
# 3            0.15  1.166190                     NaN       NaN
# 4            0.20  1.234190                     NaN       NaN
# 5            0.25  1.310351                     NaN       NaN
# 6            0.30  1.396202                     NaN       NaN
# 7            0.35  1.493671                     NaN       NaN
# 8            0.40  1.605224                     NaN       NaN
# 9            0.45  1.734061                     NaN       NaN
# 10           0.50  1.884410                     NaN       NaN
#
#    Runge-Kutta 4th Order Method
#                               x         y
# 0                          0.00  1.000000
# 1                          0.05  1.052632
# 2                          0.10  1.111111
# 3                          0.15  1.176471
# 4                          0.20  1.250000
# 5                          0.25  1.333333
# 6                          0.30  1.428571
# 7                          0.35  1.538461
# 8                          0.40  1.666666
# 9                          0.45  1.818180
# 10                         0.50  1.999998

# %%
traces = []
traces.append(utils.Get_Trace(valuesEuler, "Euler's Method")[0])
traces.append(utils.Get_Trace(valuesImproved, "Improved Euler's Method")[0])
traces.append(utils.Get_Trace(valuesRK4, "Runge-Kutta 4th Order Method")[0])
utils.Get_Comparison_Traces(traces).show()

# %%
function_srt = "-2*x**3 + 12*x**2 - 20*x + 8.5"
exact_solution = "-(1/2)*x**4 + 4*x**3 - 10*x**2 + 8.5*x + 1"

valuesEuler = solver.euler_method(function_srt, 0, 1, 0.5, 10)
values = [pt[0] for pt in valuesEuler]
exactValues = utils.Exact_Solution_R1(exact_solution, values)
valuesImproved = solver.euler_improved_method(function_srt, 0, 1, 0.5, 10)
valuesRK4 = solver.RK4(function_srt, 0, 1, 0.5, 10)

dfExact = utils.Convert_to_DF(exactValues, tagsPoints)
dfEuler = utils.Convert_to_DF(valuesEuler, tagsPoints)
dfImproved = utils.Convert_to_DF(valuesImproved, tagsPoints)
dfRK4 = utils.Convert_to_DF(valuesRK4, tagsPoints)

dfs = [dfExact, dfEuler, dfImproved, dfRK4]
tags = ["Exact Solution","Euler's Method", "Improved Euler's Method", "Runge-Kutta 4th Order Method"]
utils.Combine_DataFrames(tags, dfs)
# Out:
#    Exact Solution                    Euler's Method         \
#                 x                  y              x      y
# 0             0.0                  1            0.0  1.000
# 1             0.5   3.21875000000000            0.5  5.250
# 2             1.0   3.00000000000000            1.0  5.875
# 3             1.5   2.21875000000000            1.5  5.125
# 4             2.0   2.00000000000000            2.0  4.500
# 5             2.5   2.71875000000000            2.5  4.750
# 6             3.0   4.00000000000000            3.0  5.875
# 7             3.5   4.71875000000000            3.5  7.125
# 8             4.0   3.00000000000000            4.0  7.000
# 9             4.5  -3.78125000000000            4.5  3.250
# 10            5.0  -19.0000000000000            5.0 -7.125
#
#    Improved Euler's Method         Runge-Kutta 4th Order Method
#                          x       y                            x         y
# 0                      0.0  1.0000                          0.0   1.00000
# 1                      0.5  3.4375                          0.5   3.21875
# 2                      NaN     NaN                          1.0   3.00000
# 3                      NaN     NaN                          1.5   2.21875
# 4                      NaN     NaN                          2.0   2.00000
# 5                      NaN     NaN                          2.5   2.71875
# 6                      NaN     NaN                          3.0   4.00000
# 7                      NaN     NaN                          3.5   4.71875
# 8                      NaN     NaN                          4.0   3.00000
# 9                      NaN     NaN                          4.5  -3.78125
# 10                     NaN     NaN                          5.0 -19.00000

# %%
yExact = [y[1] for y in exactValues]
yEuler = [y[1] for y in valuesEuler]
yImproved = [y[1] for y in valuesImproved]
yRk4 = [y[1] for y in valuesRK4]

absolute_errorE = utils.Get_Absolute_Error(yExact, yEuler)
absolute_errorI = utils.Get_Absolute_Error(yExact, yImproved)
absolute_errorRk = utils.Get_Absolute_Error(yExact, yRk4)

relative_errorE = utils.Get_Relative_Error(yExact, yEuler)
relative_errorI = utils.Get_Relative_Error(yExact, yImproved)
relative_errorRk = utils.Get_Relative_Error(yExact, yRk4)

listAbsolute = []
listAbsolute.append(absolute_errorE)
listAbsolute.append(absolute_errorI)
listAbsolute.append(absolute_errorRk)
listRelative = []
listRelative.append(relative_errorE)
listRelative.append(relative_errorI)
listRelative.append(relative_errorRk)
listAbs = zip(absolute_errorE, absolute_errorI, absolute_errorRk)
listRelative = zip(relative_errorE, relative_errorI, relative_errorRk)
tagsAbs = ["Absolute Error Euler", "Absolute Error Improved Euler", "Absolute Error RK4"]
tagsRelative = ["Relative Error Euler", "Relative Error Improved Euler", "Relative Error RK4"]
listAbsolute = list(zip(*listAbsolute))
utils.Convert_to_DF(listAbsolute, tagsAbs)
# Out:
#    Absolute Error Euler  Absolute Error Improved Euler  Absolute Error RK4
# 0               0.00000                        0.00000                 0.0
# 1               2.03125                        0.21875                 0.0

# %%
utils.Convert_to_DF(listRelative, tagsRelative)
# Out:
#    Relative Error Euler  Relative Error Improved Euler  Relative Error RK4
# 0              0.000000                       0.000000                 0.0
# 1              0.631068                       0.067961                 0.0

# %%
traces = []
traces.append(utils.Get_Trace(valuesEuler, "Euler's Method")[0])
traces.append(utils.Get_Trace(valuesImproved, "Improved Euler's Method")[0])
traces.append(utils.Get_Trace(valuesRK4, "Runge-Kutta 4th Order Method")[0])
utils.Get_Comparison_Traces(traces).show()
